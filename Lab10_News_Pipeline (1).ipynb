# %%
import langchain
import langchain_community
import langchain_groq

print("All packages installed successfully!")
# Out:
# /tmp/ipykernel_1121/724835744.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   import langchain_community
# All packages installed successfully!

# %%
# !pip install requests==2.32.4 --quiet

# %%
# !pip install -U ddgs

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(api_key="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", model="llama-3.1-8b-instant", temperature=0.3)

# %%
from langchain_community.tools import DuckDuckGoSearchResults
search = DuckDuckGoSearchResults()
def search_agent(topic):
    return search.run(f'latest news about {topic}')
# Out:
# /tmp/ipykernel_3319/2188883379.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import DuckDuckGoSearchResults

# %%
def summariser_agent(raw_results): return llm.invoke( 'Summarise these news results into 3 short bullet points:\n' + raw_results).content

# %%
def report_agent(topic, summary): return llm.invoke( f'Create a short Markdown report titled "News: {topic}". ' f'Use a heading and these points:\n{summary}').content

# %%
topic = 'artificial intelligence'
raw = search_agent(topic) # Agent 1
summary = summariser_agent(raw) # Agent 2
report = report_agent(topic, summary) # Agent 3
with open('news_report.md', 'w') as f:
    f.write(report)
print(report)
print('\nSaved as news_report.md (see the Files panel on the left).')
# Out:
# # News: Artificial Intelligence
#
# ## Summary of Recent Developments
#
# Here are 3 short bullet points summarizing the news results:
#
# * Goldman Sachs has hired Google's Evan Kotsovinos as a partner and engineering head, as the company continues to invest in artificial intelligence.
# * TechCrunch provides news coverage on artificial intelligence, machine learning, and the companies building them, while also discussing the ethical issues raised by AI.
# * Multiple news sources, including the BBC, TechCrunch, and Reuters, are delivering the latest updates on artificial intelligence, machine learning, and deep learning worldwide.
#
# Saved as news_report.md (see the Files panel on the left).

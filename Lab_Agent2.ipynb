# %%
# !pip install langgraph langchain-groq -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.1 MB/s eta 0:00:00

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(api_key="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",

               model="llama-3.1-8b-instant", temperature=0)

# %%
from typing import TypedDict, List



class ChatState(TypedDict):

    messages: List[str]     # the running conversation

    name: str               # remembered user name

    preferences: str        # remembered preferences

# %%
def chatbot(state: ChatState) -> dict:

    user_msg = state['messages'][-1]



    # very simple memory rules for a beginner demo

    name = state.get('name', '')

    prefs = state.get('preferences', '')

    if 'my name is' in user_msg.lower():

        name = user_msg.lower().split('my name is')[-1].strip().title()

    if 'i like' in user_msg.lower():

        prefs = user_msg.lower().split('i like')[-1].strip()



    context = f"The user's name is {name}. They like {prefs}."

    reply = llm.invoke(context + ' Reply to: ' + user_msg).content



    return {'messages': state['messages'] + [reply],

            'name': name, 'preferences': prefs}

# %%
from langgraph.graph import StateGraph, START, END



builder = StateGraph(ChatState)

builder.add_node('chatbot', chatbot)

builder.add_edge(START, 'chatbot')

builder.add_edge('chatbot', END)

graph = builder.compile()

# %%
state = {'messages': [], 'name': '', 'preferences': ''}



while True:

    user = input('You: ')

    if user.lower() == 'quit':

        break

    state['messages'].append(user)

    state = graph.invoke(state)

    print('Bot:', state['messages'][-1])
# Out:
# You: My name is Geetha Sree and I am devotee of Hanuman
# Bot: Namaste Geetha Sree Ji,
#
# It's a pleasure to connect with a devotee of Lord Hanuman, the mighty and powerful monkey god. Hanuman is revered for his unwavering devotion to Lord Rama and his unshakeable faith in the divine. His strength, courage, and loyalty are qualities that inspire many.
#
# What is it about Lord Hanuman that resonates with you, and how do you incorporate his teachings and principles into your daily life?
# You: strength and courage and i love to be a strong independent like hanuman
# Bot: Namaste Geetha Sree,
#
# It's wonderful to hear that you're a devotee of Hanuman, the epitome of strength and courage. His unwavering dedication to Lord Rama and his unshakeable faith in the divine are truly inspiring.
#
# As a devotee of Hanuman, you must be aware of his incredible physical strength, agility, and bravery. He was able to lift the mountain of Kailash and carry it to Lanka, showcasing his incredible physical prowess. But what's even more remarkable is his mental strength and courage, which allowed him to overcome countless challenges and obstacles in his journey.
#
# Hanuman's strength and courage are not just physical, but also spiritual. He was able to overcome his own ego and limitations to serve Lord Rama and his mission. He was able to tap into his inner strength and courage to face the challenges of the world and emerge victorious.
#
# As a devotee of Hanuman, you can draw inspiration from his strength and courage to become a strong and independent individual. You can cultivate your own inner strength and courage by practicing devotion, self-discipline, and self-awareness. You can also learn from Hanuman's example of humility, compassion, and selflessness.
#
# Remember, Geetha Sree, that strength and courage are not just physical attributes, but also mental and spiritual ones. By cultivating these qualities, you can become a powerful and independent individual, capable of overcoming any challenge that comes your way.
#
# May the blessings of Lord Hanuman be upon you, Geetha Sree. May you continue to draw inspiration from his strength and courage, and may you become a shining example of devotion and dedication to the world.
#
# Jai Hanuman!
# You: thank you
# Bot: Namaste Geetha Sree,
#
# It's a pleasure to interact with a devotee of Lord Hanuman. May the blessings of the mighty monkey god be upon you.
#
# How can I assist you today?
# You: give a beautiful inspirational image of hanuman
# Bot: **Namaste Geetha Sree,**
#
# May the blessings of Lord Hanuman be upon you. Here's a beautiful inspirational image of the mighty Hanuman, the embodiment of devotion, strength, and courage.
#
# [Image: A majestic painting of Lord Hanuman standing tall, with his powerful arms crossed, and a gentle smile on his face. His eyes shine bright with devotion, and his presence radiates an aura of protection and strength. In the background, a serene landscape of the Himalayas, with the sun setting behind the mountains, casting a warm golden glow.]
#
# **"Jai Shri Ram"**
#
# May this image inspire you to walk the path of devotion, just like Lord Hanuman, and may his blessings guide you through life's challenges. Remember, "Where there is devotion, there is strength."
#
# **Your friend,**
# [Your Name]
#
# P.S. I'd love to hear about your favorite Hanuman mantra or story. Share it with me, and let's spread the love and devotion for the mighty Lord Hanuman!
# You: i like hanuman chalisa
# Bot: Namaste Geetha Sree,
#
# I'm glad to hear that you like Hanuman Chalisa. It's a sacred and powerful devotional hymn that has been a source of inspiration and solace for many devotees of Lord Hanuman. The Chalisa is a beautiful expression of devotion, gratitude, and surrender to the divine.
#
# As a devotee of Hanuman, you must be familiar with the story of Lord Rama and Hanuman's unwavering loyalty and devotion to him. Hanuman's selfless love and dedication to Lord Rama are a shining example of the power of devotion and the importance of serving a higher purpose.
#
# Do you have a favorite verse or line from the Hanuman Chalisa that resonates with you, or a special memory associated with reciting it?
# You: enough for today bye
# Bot: Namaste Geetha Sree,
#
# May the blessings of Lord Hanuman be upon you. It was a pleasure conversing with you. I hope you had a wonderful time reciting the Hanuman Chalisa today. May the divine energy of Lord Hanuman fill your heart with peace and devotion.
#
# Until we meet again, may the mantra "Shri Ram Jai Ram Jai Jai Ram" echo in your heart.
#
# Bye for now, Geetha Sree.
# You: bye
# Bot: Namaste Geetha Sree,
#
# May the blessings of Lord Hanuman be upon you. I hope you had a wonderful day reciting the Hanuman Chalisa and seeking the divine guidance of the mighty monkey god. May his strength and devotion inspire you to walk the path of righteousness.
#
# Until we meet again, may Lord Hanuman's love and protection surround you.
#
# Jai Bajrangbali!
